# %% [markdown]
# <a href="https://colab.research.google.com/github/maiaragoudapatil-art/python_begins/blob/main/pythonlearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dict
info={
    "name":"Vijay",
    "age":20,
    "like":"sleeping",
    "hobbie":"violin",
    "subject" : ["python","C"],
    12:298
}

# %%
print(info)
print(info["subject"])
# Out:
# {'name': 'Vijay', 'age': 20, 'like': 'sleeping', 'hobbie': 'violin', 'subject': ['python', 'C'], 12: 298}
# ['python', 'C']

# %%
info["name"]="Henrry"
info["surname"]="Lau"

# %%
print(info)
# Out:
# {'name': 'Henrry', 'age': 20, 'like': 'sleeping', 'hobbie': 'violin', 'subject': ['python', 'C'], 12: 298, 'surname': 'Lau'}

# %%
#null_dist
null={}
print(null)
# Out:
# {}

# %%
#nested dist
student={
    "name":"jack",
    "subject":{
        "phy":50,
        "chem":60,
        "math":70
    },
    "age":20,
    "like":"sleeping",
    "hobbie":"violin",
}

# %%
print(student)
# Out:
# {'name': 'jack', 'subject': {'phy': 50, 'chem': 60, 'math': 70}, 'age': 20, 'like': 'sleeping', 'hobbie': 'violin'}

# %%
print(student["subject"]["chem"])
# Out:
# 60

# %%
#dict_methoid
print(student.keys())
#the answer willbe in form of tuple
# Out:
# dict_keys(['name', 'subject', 'age', 'like', 'hobbie'])

# %%
print(student.values())
# Out:
# dict_values(['jack', {'phy': 50, 'chem': 60, 'math': 70}, 20, 'sleeping', 'violin'])

# %%
print(student.items())
# Out:
# dict_items([('name', 'jack'), ('subject', {'phy': 50, 'chem': 60, 'math': 70}), ('age', 20), ('like', 'sleeping'), ('hobbie', 'violin')])

# %%
print(student.get("name"))
# Out:
# jack

# %%
print(list(student.keys()))
# Out:
# ['name', 'subject', 'age', 'like', 'hobbie']

# %%
print(len(student))#dict length
print(len(list(student.keys())))
print(len(list(student.values())))
print(len(list(student.items())))
# Out:
# 5
# 5
# 5
# 5

# %%
student.update({"city":"bangalore"})
print(student)
# Out:
# {'name': 'jack', 'subject': {'phy': 50, 'chem': 60, 'math': 70}, 'age': 20, 'like': 'sleeping', 'hobbie': 'violin', 'city': 'bangalore'}

# %%
#sets
collection={1,3,4,5,"jam",5,6, "hello","myline","moomo",9}
print(collection)
print(type(collection))
#set gives the answer in unorder
# Out:
# {1, 3, 4, 5, 6, 9, 'myline', 'moomo', 'jam', 'hello'}
# <class 'set'>

# %%
#emptyset
collection9={}
collection=set()
collection2=()
print(type(collection))
print(type(collection9))
print(type(collection2))
# Out:
# <class 'set'>
# <class 'dict'>
# <class 'tuple'>

# %%
collection.add("New airline")
collection.add((4.56,43,32))
print(collection)
#we can add tuples but not list
# Out:
# {'New airline', (4.56, 43, 32)}

# %%
collection.add([4.56,43,32])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1489039917.py in <cell line: 0>()
# ----> 1 collection.add([4.56,43,32])
#
# TypeError: unhashable type: 'list'

# %%
collection.remove()
collection.clear()
collection.pop()

# %%
set1={1,2,3,4}
set2={4,5,6,7,8,9}
print(set1.union(set2))
print(set1.intersection(set2))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {4}
